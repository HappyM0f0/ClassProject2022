# %%
import numpy as np
import pandas as pd
from city_to_state import city_to_state_dict

# %%
# Load in csv
df = pd.read_csv("data_bucketed.csv" , index_col=False , encoding = 'utf-8')
df.drop(labels="Index",axis = 1, inplace=True)
df.head()
# Out:
#          City  quantity score  business score  Cost of Living Index  Bucket
# 0  Charleston            0.28            1.62                  83.9       1
# 1    Danville            0.02            0.26                  83.9       1
# 2    Richmond            0.33            1.95                  84.2       1
# 3  Huntington            0.07            0.44                  84.3       1
# 4  Portsmouth            0.05            0.39                  84.7       1

# %%
cdf = pd.DataFrame.from_dict(city_to_state_dict, orient="index")
cdf.reset_index(inplace=True)
cdf.rename(columns={'index':'City',0:"State"}, inplace=True)

# %%
cdf
# Out:
#                        City        State
# 0     East Rancho Dominguez   California
# 1                   Clinton  Mississippi
# 2                    Nanuet     New York
# 3              Sand Springs     Oklahoma
# 4              Middle River     Maryland
# ...                     ...          ...
# 2370               Hartford  Connecticut
# 2371              New Haven  Connecticut
# 2372                Shelton  Connecticut
# 2373               New York     New York
# 2374             Washington           DC
#
# [2375 rows x 2 columns]

# %%
list(cdf.columns.values)
# Out:
# ['City', 'State']

# %%
results = pd.merge(df,cdf,how="left",on="City")

# %%
results.sample(50)
# Out:
#                City  quantity score  business score  Cost of Living Index  \
# 101         Houston            1.34            3.80                  95.8
# 112          Tucson            0.19            1.17                  97.7
# 86        Iowa City            0.05            0.40                  93.5
# 25    Michigan City            0.05            0.30                  87.8
# 109       Rochester            0.16            1.31                  97.3
# 163    Fort Collins            0.17            1.43                 109.2
# 103         Reading            0.03            0.16                  96.0
# 28          Memphis            0.16            0.90                  88.2
# 60            Fargo            0.02            0.23                  91.4
# 26      Little Rock            0.17            1.08                  88.0
# 99     Harrisonburg            0.02            0.41                  95.5
# 122  Virginia Beach            0.20            0.98                  99.0
# 74      New Orleans            0.35            3.80                  92.4
# 82          Detroit            1.19            3.80                  93.2
# 94            Ocala            0.02            0.17                  94.5
# 78            Tyler            0.03            0.22                  92.8
# 13          Wichita            0.11            0.58                  86.8
# 54      Baton Rouge            0.04            0.29                  91.1
# 19    Oklahoma City            0.23            1.31                  87.3
# 92        Brunswick            0.02            0.19                  94.4
# 148         Phoenix            1.58            3.80                 104.3
# 136         Orlando            0.84            3.80                 101.4
# 17    Bowling Green            0.01            0.12                  87.0
# 172          Denver            2.36            3.80                 112.1
# 138          Ithaca            0.08            0.50                 101.7
# 69      Idaho Falls            0.02            0.17                  91.7
# 104        Lakeland            0.02            0.24                  96.4
# 76      San Antonio            0.48            3.80                  92.7
# 18       South Bend            0.06            0.32                  87.2
# 145       Asheville            0.12            0.64                 103.3
# 66         Lawrence            0.01            0.16                  91.6
# 165         Shelton            0.01            0.12                 109.6
# 155          Austin            3.20            3.80                 106.6
# 128         Chicago            4.37            3.80                 100.1
# 4        Portsmouth            0.05            0.39                  84.7
# 183        New York           11.43            3.80                 128.0
# 56      Chattanooga            0.23            1.34                  91.2
# 144     Carson City            0.02            0.31                 103.0
# 44        St. Louis            0.46            3.36                  89.6
# 158         Medford            0.02            0.47                 107.5
# 130         Atlanta            2.59            3.80                 100.3
# 140   Atlantic City            0.01            0.14                 102.0
# 102      Harrisburg            0.06            0.36                  95.8
# 53        Lexington            0.18            2.52                  91.1
# 79      Albuquerque            0.20            3.58                  92.9
# 170      Providence            0.21            1.34                 111.5
# 88     Grand Rapids            0.21            1.15                  93.7
# 173         Modesto            0.02            0.16                 112.3
# 23      Springfield            0.09            0.67                  87.5
# 29           Canton            0.02            0.18                  88.2
#
#      Bucket           State
# 101       1           Texas
# 112       1         Arizona
# 86        1            Iowa
# 25        1         Indiana
# 109       1        New York
# 163       2        Colorado
# 103       1   Massachusetts
# 28        1       Tennessee
# 60        1    North Dakota
# 26        1        Arkansas
# 99        1        Virginia
# 122       1        Virginia
# 74        1       Louisiana
# 82        1        Michigan
# 94        1         Florida
# 78        1           Texas
# 13        1          Kansas
# 54        1       Louisiana
# 19        1        Oklahoma
# 92        1         Georgia
# 148       2         Arizona
# 136       2         Florida
# 17        1            Ohio
# 172       2        Colorado
# 138       2        New York
# 69        1           Idaho
# 104       1         Florida
# 76        1           Texas
# 18        1         Indiana
# 145       2  North Carolina
# 66        1   Massachusetts
# 165       2     Connecticut
# 155       2           Texas
# 128       2        Illinois
# 4         1   New Hampshire
# 183       3        New York
# 56        1       Tennessee
# 144       2          Nevada
# 44        1        Missouri
# 158       2          Oregon
# 130       2         Georgia
# 140       2      New Jersey
# 102       1    Pennsylvania
# 53        1        Kentucky
# 79        1      New Mexico
# 170       2    Rhode Island
# 88        1        Michigan
# 173       2      California
# 23        1   Massachusetts
# 29        1         Georgia

# %%
# Find null 
r_bool = results["State"].isnull()
nan_df = results[r_bool]

# %%
len(nan_df)
# Out:
# 0

# %%
nan_df
# Out:
# Empty DataFrame
# Columns: [City, quantity score, business score, Cost of Living Index, Bucket, State]
# Index: []

# %%
reordered_results = results[["City", "State", "quantity score","business score","Cost of Living Index","Bucket"]]

# %%
reordered_results.to_csv("data_states.csv")
