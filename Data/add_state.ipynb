# %%
import numpy as np
import pandas as pd
from city_to_state import city_to_state_dict

# %%
# Load in csv
df = pd.read_csv("data_bucketed.csv" , index_col=False , encoding = 'utf-8')
df.drop(labels="Index",axis = 1, inplace=True)
df.head()
# Out:
#          City  quantity score  business score  Cost of Living Index  Bucket
# 0  Charleston            0.28            1.62                  83.9       1
# 1    Danville            0.02            0.26                  83.9       1
# 2    Richmond            0.33            1.95                  84.2       1
# 3  Huntington            0.07            0.44                  84.3       1
# 4  Portsmouth            0.05            0.39                  84.7       1

# %%
cdf = pd.DataFrame.from_dict(city_to_state_dict, orient="index")
cdf.reset_index(inplace=True)
cdf.rename(columns={'index':'City',0:"State"}, inplace=True)

# %%
cdf
# Out:
#                        City        State
# 0     East Rancho Dominguez   California
# 1                   Clinton  Mississippi
# 2                    Nanuet     New York
# 3              Sand Springs     Oklahoma
# 4              Middle River     Maryland
# ...                     ...          ...
# 2370        Charlottesville     Virginia
# 2371               Hartford  Connecticut
# 2372              New Haven  Connecticut
# 2373                Shelton  Connecticut
# 2374               New York     New York
#
# [2375 rows x 2 columns]

# %%
list(cdf.columns.values)
# Out:
# ['City', 'State']

# %%
results = pd.merge(df,cdf,how="left",on="City")

# %%
results.sample(50)
# Out:
#               City  quantity score  business score  Cost of Living Index  \
# 131        Spokane            0.10            0.64                 100.4
# 130        Atlanta            2.59            3.80                 100.3
# 45       Lafayette            0.18            1.46                  89.6
# 183       New York           11.43            3.80                 128.0
# 56     Chattanooga            0.23            1.34                  91.2
# 39       Champaign            0.04            0.27                  89.0
# 63     Kansas City            0.59            3.80                  91.6
# 102     Harrisburg            0.06            0.36                  95.8
# 159      New Haven            0.16            2.10                 107.7
# 52      Greensboro            0.04            0.35                  91.0
# 146   Philadelphia            1.70            3.80                 103.4
# 7            Flint            0.02            0.14                  85.7
# 50        Appleton            0.02            0.17                  90.7
# 65       Knoxville            0.11            0.76                  91.6
# 27    Cedar Rapids            0.05            0.29                  88.1
# 189    Los Angeles           11.23            3.80                 140.6
# 62            Ames            0.03            0.25                  91.5
# 135          Tampa            0.83            3.80                 101.4
# 182        Bozeman            0.04            0.28                 125.3
# 147       Missoula            0.05            0.43                 103.4
# 91         Roanoke            0.01            0.14                  94.1
# 166          Miami            3.21            3.80                 110.1
# 114      Charlotte            0.82            3.80                  97.9
# 87       Lynchburg            0.01            0.10                  93.6
# 24          Toledo            0.02            0.17                  87.5
# 64      Louisville            0.27            2.70                  91.6
# 82         Detroit            1.19            3.80                  93.2
# 71            Erie            0.03            0.21                  91.8
# 104       Lakeland            0.02            0.24                  96.4
# 165        Shelton            0.01            0.12                 109.6
# 79     Albuquerque            0.20            3.58                  92.9
# 145      Asheville            0.12            0.64                 103.3
# 151       Santa Fe            0.06            0.46                 105.1
# 73      Cincinnati            0.50            3.80                  92.4
# 109      Rochester            0.16            1.31                  97.3
# 25   Michigan City            0.05            0.30                  87.8
# 181        Seattle            3.49            3.80                 124.6
# 172         Denver            2.36            3.80                 112.1
# 127  State College            0.04            0.28                  99.8
# 10          Monroe            0.01            0.13                  86.5
# 120     Wilmington            0.31            3.80                  99.0
# 150       Hartford            0.22            1.55                 104.8
# 108        Buffalo            0.20            3.28                  97.3
# 92       Brunswick            0.02            0.19                  94.4
# 148        Phoenix            1.58            3.80                 104.3
# 12          Peoria            0.01            0.15                  86.7
# 16         Midland            0.03            0.42                  87.0
# 2         Richmond            0.33            1.95                  84.2
# 111    Gainesville            0.07            0.50                  97.3
# 32        Columbus            0.76            3.80                  88.5
#
#      Bucket           State
# 131       2      Washington
# 130       2         Georgia
# 45        1       Louisiana
# 183       3        New York
# 56        1       Tennessee
# 39        1        Illinois
# 63        1          Kansas
# 102       1    Pennsylvania
# 159       2     Connecticut
# 52        1  North Carolina
# 146       2    Pennsylvania
# 7         1        Michigan
# 50        1       Wisconsin
# 65        1       Tennessee
# 27        1            Iowa
# 189       4      California
# 62        1            Iowa
# 135       2         Florida
# 182       3         Montana
# 147       2         Montana
# 91        1        Virginia
# 166       2         Florida
# 114       1  North Carolina
# 87        1        Virginia
# 24        1            Ohio
# 64        1        Colorado
# 82        1        Michigan
# 71        1        Colorado
# 104       1         Florida
# 165       2     Connecticut
# 79        1      New Mexico
# 145       2  North Carolina
# 151       2      New Mexico
# 73        1            Ohio
# 109       1        New York
# 25        1         Indiana
# 181       3      Washington
# 172       2        Colorado
# 127       1    Pennsylvania
# 10        1      Washington
# 120       1  North Carolina
# 150       2     Connecticut
# 108       1       Minnesota
# 92        1         Georgia
# 148       2         Arizona
# 12        1         Arizona
# 16        1           Texas
# 2         1        Kentucky
# 111       1           Texas
# 32        1         Georgia

# %%
# Find null 
r_bool = results["State"].isnull()
nan_df = results[r_bool]

# %%
len(nan_df)
# Out:
# 0

# %%
nan_df
# Out:
# Empty DataFrame
# Columns: [City, quantity score, business score, Cost of Living Index, Bucket, State]
# Index: []

# %%
reordered_results = results[["City", "State", "quantity score","business score","Cost of Living Index","Bucket"]]

# %%
reordered_results.to_csv("data_states.csv")
